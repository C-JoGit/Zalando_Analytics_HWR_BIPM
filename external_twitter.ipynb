# %%
import sys
sys.path.append('../')
import functions
exec(open('./functions.py', encoding="utf8").read())

demoji.download_codes()
# Out:
# Downloading emoji data ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ... OK (Got response in 0.42 seconds)
# Writing emoji data to C:\Users\chiso\.demoji\codes.json ...
# ... OK
# Downloading emoji data ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chiso\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ... OK (Got response in 0.41 seconds)
# Writing emoji data to C:\Users\chiso\.demoji\codes.json ...
# ... OK
# Downloading emoji data ...
# ... OK (Got response in 0.42 seconds)
# Writing emoji data to C:\Users\chiso\.demoji\codes.json ...
# ... OK

# %%
# csv file has no header, hence has to be read without headers

a = pd.read_csv(r"external data\training.1600000.processed.noemoticon.csv", header=None)

# %%
a.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
# rename the columns
a.columns = ['target', 'ids', 'date', 'flag', 'user', 'text']
a.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
a['clean'] = clean_complete(a.text)
a.head()
# Out:
# <string>:49: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:56: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:57: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:58: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:71: FutureWarning: The default value of regex will change from True to False in a future version.
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
#
#                                                clean
# 0             awww bummer shoulda got david carr day
# 1  upset update facebook texting result school to...
# 2          dived times ball managed save rest bounds
# 3                              body feels itchy like
# 4                                       behaving mad

# %%
a['text'][4]
# Out:
# "@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there. "

# %%
a["lemmatized"] = lemmatize(a.clean)
a.head()

# %%
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
#
#                                                clean
# 0             awww bummer shoulda got david carr day
# 1  upset update facebook texting result school to...
# 2          dived times ball managed save rest bounds
# 3                              body feels itchy like
# 4                                       behaving mad

# %%
# Out:
# now right get nice spring like weather',
#  'pity youtube currently block china vids',
#  'happen hightlight life',
#  'good leather sofa world office mean work',
#  'day internet get uncapped',
#  'well day lodge belly',
#  'love atekinzz soo miss',
#  'wanna sneak zoo play kitty',
#  'hope get sick',
#  'do not think cause cousin birthday party',
#  'sweet little man fall asleep wait daddy big brother home poor baby miss today',
#  'angel going miss athlete weekend',
#  'trust hard',
#  'watch consider today yaknow shawnna tomomorrow need bestfriend',
#  'grr want reading will not leave read',
#  'atekinzz world',
#  'suppose date',
#  'pears brie bottle cabernet quot win date tad hamilton quot gawwd life flash forward cat',
#  'crap need dress',
#  'yeah know horrible ugh saddening',
#  'geez fun',
#  'wanna punk rock band',
#  'lot angst tuesday afternoon',
#  'glad britney isn crazy anymore hell sad cook county',
#  'huuuge headache omg feel like crap',
#  'sorry',
#  'sorry rooting',
#  'man take forever',
#  '',
#  'list item ebay sell take forever coleman watch hills season premier',
#  'get presentation slide cry week hard week',
#  'lose',
#  'like previously skin thing start season like go straight intro like',
#  'wish pretty good scaring shit people',
#  'go sound vain running fav lip gloss',
#  'click link screams quot spider spider quot know well yucky',
#  'time work sick',
#  'imac come indonesia states',
#  'dammit need stop buy furniture',
#  'half asleep turn laptop',
#  'death peaceful life bite',
#  'think lose net sure hope',
#  'test footage girlfriend dark underxposed',
#  'tough game watch tonight state finally go bed stay watch season premiere hill',
#  'jruby support hpricot version',
#  'unlike sister',
#  'frake app store pissing',
#  'log need study',
#  'have problem access ttb',
#  'strongly dislike people stupid comment do not know story',
#  'sorry emma swarley goldfish sad',
#  'tweet go aren miss guy tonight',
#  'sleep face kinda swollen let allergic thing thursday school tomorrow doubtful',
#  'izzy cat tree stare floor chase run',
#  'officially ban godaddy com comp head hurt small print waste happily go boba',
#  'pretty scary',
#  'mine find hard fit',
#  'good morning ready want bed',
#  'hate wait mail',
#  'wheat bread dollar store toast nicely go taxis call early night',
#  'kutner mean know go happen sad house sad',
#  'goonite',
#  'ill cinema',
#  'fall asleep mean christina',
#  'hey remember time friend ugh vomit sick need sleep',
#  'lymph node massive rahm emanuel ball right',
#  'suck think able listen xbox fancast tonite',
#  'miss play trumpet',
#  'throat sore mean go day camp friday sure',
#  'know exactly feel',
#  'work',
#  'bed time sigh morning week wednesday',
#  'jesus camp yeah',
#  'happen today forget go dress shopping opera tomorrow',
#  'turtle better mac last long move fast',
#  'soak pleasant',
#  'sorry hear maggie thought mum',
#  'email hope feel well',
#  'dead gettin wen leavin',
#  'tell close california lol',
#  '',
#  'stupid arrange marriage convert marry love',
#  'say loose imply',
#  'poor sandra cantu cantu family prayer sick world live',
#  'fuck omg austins man love',
#  'cry hard matthew die',
#  'sad foot macbook fall sad foot macbook fall',
#  'thing like twitter',
#  'absolutely',
#  'fill curry true indian come',
#  'soooo cold right',
#  'lol kant believe cam get beat upp sooo embarasssiiiin',
#  'good knight hun look forward tweet hate miss fun cuz time difference',
#  'tumblr exactly feel wear � tie �',
#  'hahaa realize quot impune quot definitely be not word want dang unclever',
#  'watch old video dance team make miss',
#  'wahh csi dvr love money go to watch sleep goodnight tweeter',
#  'struggle hard inventory',
#  'hate',
#  'haha ballin get bill paaaaay',
#  'day want work home crap',
#  'wait game episodes confuse',
#  'haha cry guess',
#  'statistics bunch mumbo jumbo',
#  'get sadly work moment',
#  'evict',
#  'enjoy learn css',
#  'brian fuck lol reply message miss',
#  'dvr go watch apparently dish network go miss catch rerun',
#  'lmao wait season come summe boo hot dry ass weather',
#  'set foot ground miss eyelid people',
#  'english professor ashamed',
#  'wish frog weren extinct',
#  'come home cross county tire',
#  'want walk home snow want pick',
#  'lauren stubborn love love feel bad lol',
#  'grouchy want bmar',
#  'heart broken morning dropping foo pre school understand moms quot heart break quot',
#  'feel hurt',
#  'mood chocolate want miniature reese cup',
#  'heat like oven feel sick nwo',
#  'come chat minute',
#  'boredd colddd internet keep stuff',
#  'horrible nightmare night affect sleep tired',
#  'lonely company female new york',
#  'lose ignaciu prepatory school haha',
#  'yeah depressing stuff like get',
#  'problem tongue cheek remark lot acronym',
#  'hey say matt go to ballistic disappointed good tho',
#  'ugh horrible ending sandra kantu story prayer',
#  'hate allergic want puppy soo bad think cool name',
#  'morning folk yawn away horse hope twitter better behave today night travesty',
#  'miss',
#  'sorry hear loss year far',
#  'gossip girl repeat',
#  'reckon',
#  'find hard use twitter',
#  'stuck house day',
#  'sad know',
#  '',
#  'maybe year tax return girl dream right',
#  'work tired hell feel cold come',
#  'april isn come soon',
#  'cream eye herpe ocular herpe different strain okay',
#  'get to repeat art folio cuz old term work get wet',
#  'ready weekend monday',
#  'umm nope think insomniac plus get flu lll sleepin like phuckin fish outta water minute',
#  'finland sleeping night time',
#  'wait try prolly wait weekend earliest',
#  'shiner take bed blanket',
#  'april isn come soon',
#  'want',
#  'need bank tomorrow break',
#  'earthquake italy sadden hour away naple family',
#  'sleep stress week come',
#  'yea work hack server player thing folk',
#  'hurt ankle go',
#  'no manage send trash noticing feel',
#  'lose free copy radioactive ipod grr buy nother coz come paper',
#  'shit',
#  'photoshop hate crash',
#  'vacation make feel sick',
#  'shouldn go',
#  'listen murd wonder chillen miss crazy sex life',
#  'shoot careful luisa',
#  'sure ruin gift whitney cell easter',
#  'beso hollywood tire',
#  'want wake early tomorrow damn work',
#  'finish watch movie prayer bobby break heart',
#  'myki horrible',
#  'dog today run',
#  'sorry hear dnf run tonight risk bad coord ftf',
#  'disgruntled people write esn hit day pull top',
#  'ohh omg lmao cry right lol kutnerrrr well',
#  'come running take shower low stomach hurt exercise',
#  'watch fallon mom working project school hard',
#  'min till home time count craving visit mac store close time',
#  'sorry hear care',
#  'hmmm greed good motivate individual well take away',
#  'brat rub want mocha',
#  'kutnerrrr think ugh kutner kal penn bright star',
#  'mom wish good luck',
#  'hate homework head hurt bad',
#  'get ebay blue item want jump bidder hour hour well hope',
#  'know little depressed ate night leftover today',
#  'living room suffer fatal partion lose itunes library go doc pic',
#  'sad day manu season',
#  'poor spunky sad rotti path know feel',
#  'sooo sad right need hug',
#  'want step brother home worried do not know hope know care',
#  'get watch hill love excited episode sad season',
#  'aww stinks hugs',
#  'tired feel like crap world feel crummy happy usb disco mouse',
#  'do not want believe read buu sad',
#  'wonder gamebattle',
#  'white trash outnumber',
#  'true use',
#  'spring break celebrate',
#  'morning bah car win start wait anwb',
#  'pretty anti memorial tattoo strictest official ban disapprove family',
#  'balamurugan longterm member team leave month miss work hope venture',
#  'sad know body crazy world live child deserve know',
#  'wanna rock maxi dress coachella lack funding',
#  'course baby scream crib night day work let boooo',
#  'home miss baby busy week ahead fri chill day guy kids egg hunt sit spiral dmb sat night easter',
#  'everytime click twitt thing myspace go dude page',
#  'horrible sorryto hear',
#  'say dtmafiaofficial do not exist jus dtmafia dun followin wht',
#  'thought support',
#  'augh eff sarth stole mil nail polish pretty',
#  'wish spring fle tour dawn neecee sigh knight',
#  'hoyts distribution website isn work great like need',
#  'like movie cillian murphy hot',
#  'wish good old cartoon come captain planet wally daria sadness',
#  'feel good abt',
#  'get text sarah',
#  'day centre point time early start guess train rammed commuter',
#  'game fall modern warfare halo odst brutal legend bioshock need cash',
#  'ugh disconcerting',
#  'actually site finally take damn russians',
#  'tweet be not go',
#  'finished delicious breakfast paris miss milk europe tastiest milk world drink',
#  'ilearn great considering final week',
#  'stress outttt',
#  'should have bern asleep hour ago',
#  'try figure twitter thing friend soo',
#  'ping custom icon look cool edge square look bad diff background',
#  'want',
#  'dunno use forum frustrated miss talk',
#  'option',
#  'unfortunately moment wasn giant squid monster',
#  'want branch midv open',
#  'sorry hear',
#  'change plan order mac instead time hit book',
#  'yup',
#  'donnie tweet stat reply jrk',
#  'nah haven receive stimulus',
#  'see tweet plz write bak havnt get reply bak',
#  'awwwww try sleep hour ago',
#  'sorry hear sad lose close love',
#  'sleep feelin like piece shit',
#  'sympathies hard decision hope old border collie sleep hug',
#  'cool will not spoil',
#  'time warp sad',
#  'true lol slap face warm end march',
#  'hate convert movie itouch',
#  'gross pimple',
#  'yea naaaaaaaaaaaaaaaaaaaam marwan accent lol',
#  'follower tonight',
#  'mom night brb figure burn',
#  'feel like quot twitterer quot tweetdeck',
#  'karate tournament week',
#  'go sleep finish statistic homework',
#  'north carolina baby be not nothing stop nba draft',
#  'sleep',
#  'reaaly miss john mayer twitters fuck rude people remove like tweet bitchfuck',
#  'go late mqu today',
#  'tired work need life',
#  'leavin work foot hurt',
#  'sad unexpected totally cry haha',
#  'superneej morning bah car win start wait anwb',
#  'homework',
#  'little sad',
#  'mom dad early',
#  'asleep hour ago',
#  'sorry hear dog',
#  'funny little thing homesick criminals breakn brownstone lawnord misty',
#  'yeah great vid quot single sell year ago',
#  'val mac iitsc clubroom sweating',
#  'awww sad sorry',
#  'updatingffe give good minute',
#  'hot compress rily workng pull muscle gng bed good night',
#  'invite quot healthy dining quot session ashok hotel today exec chef chopra damn workload skip',
#  'sorry hear dog wish happy day come',
#  'miss',
#  'cool tweet app razr',
#  'bed get to wake hella early tomorrow morning',
#  'procrastinate hate organize clothe',
#  'play new mobbler add great new feature win play music like',
#  'bestie miss',
#  'time come flawda double date seriously sorry hear',
#  'way late work client',
#  'blegghhhh work',
#  'work john muir',
#  'email yesterday respond',
#  'go long year fan',
#  'get watch new house episode definitely saddest episode',
#  'man taxis suck horrified wrong turbotax decide lot stuff turn',
#  'sleep time tomorrow go to suck',
#  'wtf kutner piss house mean wtf',
#  'know do not know say',
#  'cash rule',
#  'pick oats market eat breakfast boy time work usc late night',
#  'feel sick icecream',
#  'shockwave blah account',
#  'awww wish sydney',
#  'hahaha suriously feel like know joke',
#  'spell today totally suck',
#  'vaccinated chicken pox vaccinate old confused damn thing',
#  'school day',
#  'yawwwn get to early tomorrow ready weekend',
#  'miss home calve season sad black die morning wish bottle calf',
#  'sorry loss brother dog sam sick cushing disease',
#  'work spend hour dispatch room',
#  'new kind starburst favered sound fab cherry strawberry fav red add watermellon yucky',
#  'productive day angel',
#  'gee insomnia suck try melatonin',
#  'good hear support netbeans netbeans know',
#  'wish time rest world unfornately cairo wait mtva play',
#  'heartbroken little sandra prayer family',
#  'word finish tomorrow maybe',
#  'come background cover screen corner',
#  'write exactly line dialogue tonight give',
#  'complaint facebook change confusing',
#  'sliced finger',
#  'go town traffic bypass stink',
#  'ugh sleep wish good cuddle ass',
#  'hate software update download update tell know download',
#  'go ihop great diet kung foo pancake time rachel',
#  'internet hating night pose',
#  'jealous miss open day year',
#  'cruel have wait review come far look like star trek good film year',
#  'debate shower sleep little later tomorrow',
#  'stress culminate physical pain',
#  'need sleep',
#  'little pinky finger hurt',
#  'sorry gift card run suck',
#  'home spring break home tho',
#  'access oneindia mobi google phone android support indic language',
#  'school life sleep anymore school work',
#  'wish speak yia yia speak english',
#  'free comp lol',
#  'get ready clean house',
#  'cry friend move away tomorrow',
#  'stop nomnom share night people',
#  'think get cold catch daddy trip ruin',
#  'yeah bcoz kal penn visit lecturer anymore go to miss',
#  'procrastination start early quarter want reaaaaad write paper',
#  'apparently degress washington state miss winter',
#  'bored homee',
#  'massage great spill coke desk lame watch simpson finish hills dvds',
#  'wait fanclub chat tough favorite',
#  'mild leave inner ear infection get irritate quot block quot feeling sunday',
#  'hey nope cuteness away awhile',
#  'tuesday',
#  'haha know twitter haha',
#  'someone alarm clock phone woke get headache yesterday night',
#  'awww poor puppy',
#  'break eat buffalo wing tomorrow',
#  'sittin kayla reallly dis like have brother know stop wait day',
#  'fed bokkie birthday treat sicko',
#  'kinda bummed agency tell look go lady help create look',
#  'work laptop officially dead happy',
#  'goodness freeze',
#  'listen mom',
#  'stucked paris travel france work',
#  'think close time check close mile away',
#  'aaaaand literature review friendly cup coffee company',
#  'worried win pay buttload tax year',
#  'okay school',
#  'phoneless sleep',
#  'reeked alcohol dentist morning drunk tshirt realise huge stain dentist look disgusted',
#  'cold',
#  'sleep want dream',
#  'sleep hate night try bed early stay awake hour poo',
#  'yeah bad people like certain burrito eat man exist',
#  'sad',
#  'mum adopt auntie twitter check mum tessm awesome auntie tania',
#  'sleep wide awake get to work later boy go crappy day',
#  'struggle eam law',
#  'sleep like',
#  'bout start poor linny couldn eye open tired work tomorrow morning night',
#  'year old year old driving twist want like',
#  'suck',
#  'place day help pack painting cleaning appreciate rip wall',
#  'open partially frozen beer beer toaster oven counter kitchen smell like run speakeasy',
#  'do not know ride',
#  'sadly yes think need councile',
#  'make ready school feel like go test',
#  'smugness go train failed turn head victoria follow unpleasant tube ride city',
#  'anybody know ipod go',
#  'aww earthquake italy sad see pics news terrible',
#  'able afford extraction continue deal',
#  'pet care people try run business send suspicious mail fishing info',
#  'codez mia tho',
#  'do not work cell sleep',
#  'go nice tomorrow rain come nice weather birthday',
#  'rock band hard expert',
#  'roomie home day scratch door comforter goto large laundromat machine',
#  'hard thing schedule chat end day usually',
#  'kill character favorite show upset',
#  'jealous friend get new star trek film austin tonight',
#  'listening get bad headache drivin lesson min lucky wana sleeep',
#  'shut hungry britain home boring suckassy breakfast world miss dennys',
#  'good morning everybody pkoi fais pas beau bon coffee time',
#  'work',
#  'essay time',
#  'hey talk mom home hope wish come home easter',
#  'sure wish guy tmrw usual school interfere',
#  'kal penn leave house noooooo totally miss tonight',
#  'lose loyal',
#  'play hand bad lose half stack',
#  'early day looooooong night work',
#  'sad season wanna spencer call lauren',
#  'editing quot phipstape quot crack brew get tree',
#  'know half mean',
#  'homework homework homework',
#  'work heart today double weight station result stiff pull muscle ouch',
#  'feel bad unfollowing',
#  'tired god hate new job day',
#  'sad kutner kill fav house',
#  'happy coach stringer hof finish term paper',
#  'feel like shit way want spend birthday eve',
#  'far site check update',
#  'lot mind need money idea hire',
#  'miss',
#  'sorry hear dog',
#  'internet plague',
#  'miss soo',
#  'sodding',
#  'thought pirate bay trial verdict today apparently day',
#  '',
#  'study hall log immediately',
#  'tired crying reason try hour half tonight half get night',
#  'totally like girl option viable',
#  'far veiws site check update',
#  'listening bjork love crying',
#  'omg hills love money aww think becky buckwild go',
#  'crave tantan nabe',
#  'mon sean man',
#  'watch quot league quot make miss mint chocolate ice cream cone grand fuck',
#  'lose phone maybe grass long hope rain',
#  'hope aren refer hello new stalker lol',
#  'sleep go to night bike ride',
#  'wanna listen master',
#  'look good stuff write load uni work',
#  'feel unloved drop tweeter',
#  'london day thursday go to rain fab won london eye robbie win care bless',
#  'completely wipe reload lose bbm contact go bed sad',
#  'sayyyy whaaaa wasn invite',
#  'sleep bad consider workshop start today beginning sore throat',
#  'gosh emotional haha idk do not want old',
#  'go post story manually twitterfeed problem quiet lately',
#  'like lukewarm shower',
#  'contact need freelance work linux com get',
#  'connor febi mad',
#  'need help want buy macbook pro inlove old powerbook',
#  'man america borez lol realize send msgs idea flash',
#  'knight lovely lady sleepy',
#  'anybody know electrolyte order vitamin work feel sick',
#  'yes hasn reading post properly',
#  'italian homework weeeeee understand',
#  'turn light time',
#  'twitter hate',
#  'hate fact genuinely excited tweet',
#  'sleep',
#  'italy earthquake sad news day',
#  'rain today garden need bad',
#  'yawn yawn yawn minutes bed',
#  'ouch sound sucky',
#  'great idea itune promo codes work itunes store',
#  '',
#  'rum barrel sad rum barrel shake head horror horror',
#  'sleepless night',
#  'admit fake',
#  'love chutney',
#  'get highly bored today scanning page daddy',
#  'cooked risotto',
#  'keeeerrrrriiiiii well post thing wonderfullll say alot',
#  'yay baseball season boo yankees lose game',
#  'lose suck work today',
#  'omg exam kill know difference haif circle hemisphere',
#  'bed suddenly feel wish goodnight twitterfam',
#  'like goodnight',
#  'greaaat lappy won turn wtffffff',
#  'stick traffic journey traffic free morning help',
#  'lookin like nighter hate',
#  'stranger',
#  'debbugge old code day start well',
#  'quarter percent babe darn',
#  'come cold bad allergy way miserable',
#  'believe cutner dead house sad day santa rosa',
#  'damnit dig season reaper',
#  'gah comcast double cable internet tell quit suggest affordable company bay area',
#  'early morn duchess hadn manage cross leg time',
#  'left say',
#  'want sleep',
#  'xbox show red light mean dead need fix month microsoft',
#  'king sized bed nice sad lonely hubby puppy kitty conferencee thing',
#  'boredd gah wish sleep -PRON- have toooo muchh cooooffffeeeeeeeee bahaha',
#  'butt nosey sorry conversation interesting',
#  'fall list offend',
#  'week till sister home miss bad feeling world',
#  'go to try sleep hotel room',
#  'brilliant idea bring think spend swap bring brolly',
#  'autograph shout record dead listen',
#  'khloe get fire apprentice',
#  'biology class lip hurt',
#  'sorry tweet',
#  'grr school today',
#  'tivo get set tonight order channel',
#  'ask yesterday single tweet',
#  'ruddy money like wait surprise state hmmm seriously',
#  'sad kutner favorite new team',
#  'wow quot hello quot suck',
#  'bedtime school tomorrow book break suckssss',
#  'seat help baby paper force seat sleepy',
#  'synche contact old mobile iphone import work',
#  'concentrate',
#  'spend hour enter bureaucratic nonsense march waste time',
#  'confused',
#  'feel stupid migraine make tummy upset body ache shoot',
#  'read buyology bedtime great premise turn quot quot book lot info know',
#  'home wana sleep waste free line town assignment finish',
#  'send update plurk upload photo twitter do not update plurk zero',
#  'omg quot reader quot make',
#  'get decent exchange rate moment sterling get flog',
#  'try download tweetdeck will not download',
#  'inch snow ground counting worried poor flower',
#  'aren happy camper',
#  'thank man grateful feel unworthy attention',
#  'miss totally comin tho lastnight sooooooo fun',
#  'ohhh love sad hang',
#  'end place',
#  'sad poor boy',
#  ...]
